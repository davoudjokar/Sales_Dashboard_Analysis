# %%
import pandas as pd
import io
import ipywidgets as widgets
from IPython.display import display

upload = widgets.FileUpload(
    accept='.csv',
    multiple=False
)

display(upload)

def handle_upload(change):
    if upload.value:
        # ✅ اصلاح‌شده برای تاپل
        uploaded_file = upload.value[0]
        name = uploaded_file['name']
        content = uploaded_file['content']

        # تبدیل به DataFrame
        df = pd.read_csv(io.BytesIO(content))
        print(f"✅ فایل '{name}' با موفقیت بارگذاری شد.")
        display(df.head())

        # ذخیره global برای استفاده‌های بعدی
        globals()['df'] = df

upload.observe(handle_upload, names='value')
# Out:
# FileUpload(value=(), accept='.csv', description='Upload')
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# تعداد سطر و ستون
print("🧮 شکل داده‌ها:", df.shape)

# نام ستون‌ها
print("🧩 ستون‌ها:", df.columns.tolist())

# خلاصه آماری
df.describe()
# Out:
# 🧮 شکل داده‌ها: (7043, 21)
# 🧩 ستون‌ها: ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
import numpy as np

print("📊 میانگین هزینه ماهانه:", np.mean(df['MonthlyCharges']))
print("📉 کمترین هزینه ماهانه:", np.min(df['MonthlyCharges']))
print("📈 بیشترین هزینه ماهانه:", np.max(df['MonthlyCharges']))
print("📐 انحراف معیار:", np.std(df['MonthlyCharges']))
# Out:
# 📊 میانگین هزینه ماهانه: 64.76169246059918
# 📉 کمترین هزینه ماهانه: 18.25
# 📈 بیشترین هزینه ماهانه: 118.75
# 📐 انحراف معیار: 30.087910854936975

# %%
# مشتریانی که بیشتر از 100 دلار ماهانه پرداخت می‌کنن
df[df['MonthlyCharges'] > 100]

# مشتریانی که churn شدن (ترک کردن)
df[df['Churn'] == 'Yes']

# مشتریانی که tenure بالای 12 ماه و هنوز هستند
df[(df['tenure'] > 12) & (df['Churn'] == 'No')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# ...          ...     ...            ...     ...        ...     ...
# 7035  8456-QDAVC    Male              0      No         No      19
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %%
# میانگین هزینه ماهانه برای هر نوع قرارداد
df.groupby('Contract')['MonthlyCharges'].mean()

# تعداد مشتری براساس جنسیت
df['gender'].value_counts()

# درصد مشتریانی که churn کردن
df['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df['TotalCharges'].dtype
# Out:
# dtype('O')

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df['AvgCostPerMonth'] = df['TotalCharges'] / (df['tenure'] + 1)
df[['customerID', 'TotalCharges', 'tenure', 'AvgCostPerMonth']].head()
# Out:
#    customerID  TotalCharges  tenure  AvgCostPerMonth
# 0  7590-VHVEG         29.85       1        14.925000
# 1  5575-GNVDE       1889.50      34        53.985714
# 2  3668-QPYBK        108.15       2        36.050000
# 3  7795-CFOCW       1840.75      45        40.016304
# 4  9237-HQITU        151.65       2        50.550000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Churn', y='AvgCostPerMonth')
plt.title('💰 Avg. Cost per Month by Churn')
plt.xlabel('Churn')
plt.ylabel('Average Cost per Month')
plt.grid(True)
plt.show()
# Out:
# C:\Users\davou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['AvgCostPerMonth'], bins=40, kde=True, color='skyblue')
plt.title('📊 Distribution of Avg. Cost per Month')
plt.xlabel('Avg. Cost per Month')
plt.ylabel('Count')
plt.grid(True)
plt.show()
# Out:
# C:\Users\davou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='gender', y='AvgCostPerMonth', hue='Churn', split=True)
plt.title('🎻 Avg. Cost per Month by Gender & Churn')
plt.xlabel('Gender')
plt.ylabel('Average Cost per Month')
plt.grid(True)
plt.show()
# Out:
# C:\Users\davou\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127931 (\N{VIOLIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
